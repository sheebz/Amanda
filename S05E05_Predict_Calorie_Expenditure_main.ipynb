# %% [markdown]
# <a href="https://colab.research.google.com/github/sheebz/Amanda/blob/master/S05E05_Predict_Calorie_Expenditure_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Version tracking
VERSION = "v40"
#!pip install catboost
import os
import pandas as pd
import numpy as np
import xgboost as xgb
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import lightgbm as lgb
from sklearn.metrics import mean_squared_log_error, make_scorer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
from itertools import product
import kagglehub
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam


xgb_model = None
cb_model = None
lgb_model = None
xgb_grid = None
cb_grid = None
lgb_grid = None

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def add_categorical_aggregations(df, train_aggs=None):
    categorical_cols = ['Sex']
    numerical_cols = ['BMI', 'Heart_Rate', 'Body_Temp', 'MET_approx', 'Duration']
    if train_aggs is None:
        aggs = df.groupby('Sex')[numerical_cols].agg(['min', 'max', 'mean', 'std', 'var'])
        aggs.columns = [f"Sex_{num_col}_{stat}" for num_col, stat in aggs.columns]
        train_aggs = aggs
    df = df.merge(train_aggs, on='Sex', how='left')
    return df, train_aggs


def add_interactions_onehot(df, features, gender_col='Sex'):

    # Create one-hot columns (no need for get_dummies - we know it's binary)
    df['Male'] = df[gender_col]  # 1 if male, 0 otherwise
    df['Female'] = 1 - df[gender_col]  # Inverse

    # Create interactions
    for feat in features:
        df[f'{feat}_x_Male'] = df[feat] * df['Male']
        df[f'{feat}_x_Female'] = df[feat] * df['Female']

    # Drop temporary one-hot columns (optional)
    df.drop(['Male', 'Female'], axis=1, inplace=True)

    return df

# RMSLE scorer
def rmsle_scorer(y_true, y_pred):
    y_true = np.expm1(y_true)
    y_pred = np.expm1(y_pred)
    return np.sqrt(mean_squared_log_error(np.clip(y_true, 0, None), np.clip(y_pred, 0, None)))

rmsle_fn = make_scorer(rmsle_scorer, greater_is_better=False)

# BMR calculation
def get_bmr(row):
    if row['Sex'] == 0:  # Male
        return 66.5 + (13.75 * row['Weight']) + (5.003 * row['Height']) - (6.75 * row['Age'])
    else:  # Female
        return 655.1 + (9.563 * row['Weight']) + (1.850 * row['Height']) - (4.676 * row['Age'])


def categorize_bmi(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 25:
        return 'Normal'
    elif 25 <= bmi < 30:
        return 'Overweight'
    else:  # bmi >= 30
        return 'Obese'


def calculate_bmi(height_cm, weight_kg):
  height_m = height_cm / 100
  bmi = weight_kg / (height_m ** 2)
  return bmi

# MET estimation (adjusted duration factor)
def estimate_met(weight, hr, hr_rest, max_hr, duration):
    net_hr = hr - hr_rest
    base_mets = 0.05 * net_hr + 2
    duration_factor = 1 + (duration / 60) * 0.05
    predicted_mets = base_mets * duration_factor
    return max(1, min(predicted_mets, 20))

def add_interaction(df, prefix, features):
  from pandas.api.types import is_numeric_dtype
  for feature in features:
    feature_col = df[feature]

    for col in df.columns.to_list():
      if col.startswith(prefix):
        #print(df[col].dtype)
        #print(df[col])
        if is_numeric_dtype(df[col].dtype):
          df[f'{feature}_x_{col}'] = df[feature] * df[col]

  return df

# Data preprocessing
def get_data(datafile):
    data = pd.read_csv(datafile)
    data['Sex'] = (data['Sex'] == 'female').astype('int8')

    # Outlier capping
    for col in ['Heart_Rate', 'Body_Temp']:
        q1, q3 = data[col].quantile([0.25, 0.75])
        iqr = q3 - q1
        lower, upper = q1 - 1.0 * iqr, q3 + 1.0 * iqr
        data[col] = data[col].clip(lower, upper)

    # Features

    data['BMI'] = data.apply(lambda x: calculate_bmi(height_cm=x['Height'].astype('float32'),
                                                     weight_kg=x['Weight'].astype('float32')), axis=1)
    data['BMR'] = data.apply(get_bmr, axis=1)

    # categorical
    data['HR_Max'] = (220 - data['Age'])
    data['HR_Ratio'] = (data['Heart_Rate'] / data['HR_Max'])
    data['HR_Rest'] = data.apply(
        lambda x: (76 - 0.6 * x['Age']) * (1 - 0.2 * (1 - x['HR_Ratio'])) if (x['Sex'] == 0 and x['Age'] >= 61)
        else (80 - 0.6 * x['Age']) * (1 - 0.2 * (1 - x['HR_Ratio'])) if (x['Sex'] == 1 and x['Age'] >= 61)
        else (74 - 0.6 * x['Age']) * (1 - 0.2 * (1 - x['HR_Ratio'])) if x['Sex'] == 0
        else (78 - 0.6 * x['Age']) * (1 - 0.2 * (1 - x['HR_Ratio'])), axis=1
    )

    # Age Groups
    data['Age_Group'] = pd.cut(data['Age'], bins=[20, 40, 60, 79], labels=['Young', 'Middle', 'Senior'], include_lowest=True)
    data['Age_Young'] = (data['Age_Group'] == 'Young').astype('int8')
    data['Age_Middle'] = (data['Age_Group'] == 'Middle').astype('int8')
    data['Age_Senior'] = (data['Age_Group'] == 'Senior').astype('int8')
    data.drop('Age_Group', axis=1, inplace=True)

    # BMI Groups
    data['BMI_Class'] = data['BMI'].apply(categorize_bmi)
    data['BMI_Class'] = pd.Categorical(data['BMI_Class'], categories=[
        'Underweight', 'Normal', 'Overweight', 'Obese'
    ])
    data['BMI_Underweight'] = (data['BMI_Class'] == 'Underweight').astype('int8')
    data['BMI_Normalweight'] = (data['BMI_Class'] == 'Normal').astype('int8')
    data['BMI_Overweight'] = (data['BMI_Class'] == 'Overweight').astype('int8')
    data['BMI_Obese'] = (data['BMI_Class'] == 'Obese').astype('int8')
    data.drop('BMI_Class', axis=1, inplace=True)

    # interactions
    data['HR_Age'] = (data['Heart_Rate'] * data['Age']).astype('float32')
    data['Body_Temp_HR_Ratio'] = (data['Body_Temp'] * data['HR_Ratio']).astype('float32')
    #data['Body_Temp_Age_Interaction'] = (data['Body_Temp'] * data['Age_Group']).astype('float32')
    data['Heart_Rate_Body_Temp_Interaction'] = (data['Heart_Rate'] * data['Body_Temp']).astype('float32')
    data['Duration_Heart_Rate_Interaction'] = (data['Duration'] * data['Heart_Rate']).astype('float32')
    data['Sex_Heart_Rate_Interaction'] = (data['Sex'] * data['Heart_Rate']).astype('float32')
    data['MET_approx'] = data.apply(lambda x: estimate_met(x['Weight'], x['Heart_Rate'], x['HR_Rest'], x['HR_Max'], x['Duration']), axis=1).astype('float32')
    #data['Estimated_Calories'] = (data['BMR'] / 1440 * data['Duration'] * data['MET_approx']).astype('float32')
    data['Duration_MET_Interaction'] = (data['Duration'] * data['MET_approx']).astype('float32')  # New feature
    data['BMR_Duration'] = (data['BMR'] * data['Duration']).astype('float32')
    data['Female_Duration'] = data['Duration'].where(data['Sex'] == 1, 0).astype('float32')
    data['Male_Duration'] = data['Duration'].where(data['Sex'] == 0, 0).astype('float32')
    data['Duration_Body_Temp'] = (data['Duration'] * data['Body_Temp']).astype('float32')
    data['HR_Duration_Ratio'] = (data['Heart_Rate'] / data['Duration']).astype('float32')
    data['Age_Duration'] = (data['Age'] * data['Duration']).astype('float32')
    # v32
    data['Age_BMI_Interaction'] = (data['Age'] * data['BMI']).astype('float32')
    data['Heart_Rate_BMI_Interaction'] = (data['Heart_Rate'] * data['BMI']).astype('float32')
    data['Body_Temp_BMI_Interaction'] = (data['Body_Temp'] * data['BMI']).astype('float32')
    #data['Calories_per_Minute'] = (data['Estimated_Calories'] / data['Duration']).replace([np.inf, -np.inf], 0).astype('float32')
    #data['MET_BMI_Interaction'] = (data['MET_approx'] * data['BMI']).astype('float32')
    data['Duration_BMR_Interaction'] = (data['Duration'] * data['BMR']).astype('float32')
    #data['Heart_Rate_Estimated_Calories_Interaction'] = (data['Heart_Rate'] * data['Estimated_Calories']).astype('float32')

    for col in ['Age', 'Weight', 'Heart_Rate', 'Calories', 'Duration']:
        if col in data:
            data[col] = data[col].astype('float32')

    data = add_interaction(data, 'Age_', ['Duration', 'HR_Ratio', 'Body_Temp', 'MET_approx'])
    data = add_interaction(data, 'BMI_', ['Duration', 'HR_Ratio', 'Body_Temp', 'MET_approx'])

    data = data.drop(['Age', 'Height', 'Weight'], axis=1)
    return data

# %% [markdown]
# # Train Models

# %%
# Download dataset using kagglehub
playground_series_s5e5_path = kagglehub.competition_download('playground-series-s5e5')

train_data = get_data(os.path.join(playground_series_s5e5_path, 'train.csv'))
train_data, aggs = add_categorical_aggregations(train_data)

test_data = get_data(os.path.join(playground_series_s5e5_path, 'test.csv'))
test_data, _ = add_categorical_aggregations(test_data, aggs)
X_test_final = test_data.drop(['id'], axis=1)

X = train_data.drop(['id', 'Calories'], axis=1)
y = train_data['Calories']
y_log = np.log1p(y)
X_train, X_test, y_train_log, y_test_log = train_test_split(X, y_log, test_size=0.2, random_state=42)
y_test = np.expm1(y_test_log)
y_train = np.expm1(y_train_log)

# Subsample data for CV
X_cv, _, y_log_cv, _ = train_test_split(X, y_log, train_size=0.2, random_state=42)

BEST_CB_PARAMS = {
    'learning_rate': 0.03,
    'l2_leaf_reg': 7,
    'iterations': 600,
    'depth': 9,
    'bagging_temperature': 0, # do not change, caused increase
    'random_seed': 42,
    'task_type': 'GPU',
    'devices': '0'
}

BEST_CB_PARAMS =  {'learning_rate': 0.03, 'l2_leaf_reg': 7, 'iterations': 600, 'depth': 9, 'bagging_temperature': 0}
BEST_XGB_PARAMS = {'reg_lambda': 1.5, 'reg_alpha': 1, 'objective': 'reg:squaredlogerror', 'n_estimators': 600,
                   'max_depth': 8, 'learning_rate': 0.05, 'gamma': 0}
BEST_LGBM_PARAMS = {'reg_alpha':0.5, 'reg_lambda':0.5, 'num_leaves': 60, 'min_child_samples': 30,
                    'max_depth': 20, 'learning_rate': 0.05}


# CatBoost
# if not cb_model:
print("Starting CatBoost training...")
cb_model = CatBoostRegressor(**BEST_CB_PARAMS, random_state=42, early_stopping_rounds=20, silent=True)
cb_model.fit(X_train, y_train_log, eval_set=[(X_test, y_test_log)])
y_pred_cb_log = cb_model.predict(X_test)
y_pred_cb = np.expm1(y_pred_cb_log)  # Fix: Transform log-predictions to original scale

y_pred_final_cb_log = cb_model.predict(X_test_final)
y_pred_final_cb = np.expm1(y_pred_final_cb_log)
submission_cb = pd.DataFrame({'id': test_data['id'], 'Calories': np.clip(y_pred_final_cb, 0, None)})
submission_cb.to_csv(f'submission_cb_{VERSION}.csv', index=False)
print(f"CatBoost Test RMSLE ({VERSION}):", np.sqrt(mean_squared_log_error(y_test, np.clip(y_pred_cb, 0, None))))
print("Submission head:", submission_cb.head())
print("Submission stats:", submission_cb['Calories'].describe())
importance_cb = pd.Series(cb_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
print(f"Catboost Feature Importance ({VERSION}): {importance_cb}")

# XGBoost
if not xgb_model:
  print("Starting XGBoost training...")
  xgb_model = XGBRegressor(**BEST_XGB_PARAMS, early_stopping_rounds=20, random_state=42)
  xgb_model.fit(X_train, y_train_log, eval_set=[(X_test, y_test_log)], verbose=False)
  y_pred_xgb_log = xgb_model.predict(X_test)
  y_pred_xgb = np.expm1(y_pred_xgb_log)

  y_pred_final_xgb_log = xgb_model.predict(X_test_final)
  y_pred_final_xgb = np.expm1(y_pred_final_xgb_log)
  submission_xgb = pd.DataFrame({'id': test_data['id'], 'Calories': np.clip(y_pred_final_xgb, 0, None)})
  submission_xgb.to_csv(f'submission_xgb_{VERSION}.csv', index=False)
  print(f"XGBoost Test RMSLE ({VERSION}):", np.sqrt(mean_squared_log_error(y_test, np.clip(y_pred_xgb, 0, None))))
  importance_xgb = pd.Series(xgb_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
  print(f"XGBoost Feature Importance ({VERSION}) : {importance_xgb}")

#LightGB
if not lgb_model:
  print("Starting LightGBM training...")
  lgb_model = lgb.LGBMRegressor(**BEST_LGBM_PARAMS, random_state=42, silent=True)
  lgb_model.fit(X_train, y_train_log, eval_set=[(X_test, y_test_log)], callbacks=[lgb.early_stopping(stopping_rounds=10)])
  y_pred_lgb_log = lgb_model.predict(X_test)
  y_pred_lgb = np.expm1(y_pred_lgb_log)

  y_pred_final_lgb_log = lgb_model.predict(X_test_final)
  y_pred_final_lgb = np.expm1(y_pred_final_lgb_log)
  submission_lbg = pd.DataFrame({'id': test_data['id'], 'Calories': np.clip(y_pred_final_lgb, 0, None)})
  submission_lbg.to_csv(f'submission_lbg_{VERSION}.csv', index=False)
  print(f"LightGBM Test RMSLE ({VERSION}):", np.sqrt(mean_squared_log_error(y_test, np.clip(y_pred_lgb, 0, None))))
  importance_lgb = pd.Series(lgb_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
  print(f"LightGBM Feature Importance ({VERSION}): {importance_lgb}")

# Use existing predictions{0.05, 0.15, 0.8}
weights = {'xgboost': 0.05, 'lightgbm': 0.15, 'catboost': 0.8}
y_pred_final_ensemble_log = (weights['xgboost'] * y_pred_final_xgb_log +
                            weights['lightgbm'] * y_pred_final_lgb_log +
                            weights['catboost'] * y_pred_final_cb_log)
y_pred_ensemble_log = (weights['xgboost'] * y_pred_xgb_log +
                      weights['lightgbm'] * y_pred_lgb_log +
                      weights['catboost'] * y_pred_cb_log)

# Generate new ensemble submission
y_pred_final_ensemble = np.expm1(y_pred_final_ensemble_log)
submission_ensemble = pd.DataFrame({
    'id': test_data['id'],
    'Calories': np.clip(y_pred_final_ensemble, 0, None)
})
submission_ensemble.to_csv(f'submission_ensemble_{VERSION}.csv', index=False)
print(f"New ensemble submission head: {submission_ensemble.head()}")
print(f"New ensemble Calories stats : {submission_ensemble['Calories'].describe()}")

# Standard CV for all models
models = [(xgb_model, "XGBoost"), (lgb_model, "LightGBM"), (cb_model, "CatBoost")]
print("Starting CV...")
scores_xgb, scores_lgb, scores_cb = None, None, None
for model, name in models:
    # For XGBoost, create a new instance without early stopping
    if name == "XGBoost":
        model = XGBRegressor(
            **{
                'learning_rate': 0.05,
                'max_depth': 7,
                'n_estimators': 500,
                'reg_alpha': 3.0,
                'reg_lambda': 2.0,
                'device': 'gpu'
            },
            random_state=42
        )  # No early_stopping_rounds
    scores = cross_val_score(model, X_cv, y_log_cv, cv=5, scoring=rmsle_fn)
    if name == "XGBoost":
        scores_xgb = scores
    elif name == "LightGBM":
        scores_lgb = scores
    elif name == "CatBoost":
        scores_cb = scores
    print(f"{name} 5-Fold CV RMSLE ({VERSION}): {-scores.mean():.6f} ± {scores.std():.6f}")
print("Finished CV...")

# Validate locally
y_pred_ensemble = np.expm1(y_pred_ensemble_log)
ensemble_rmsle = np.sqrt(mean_squared_log_error(y_test, np.clip(y_pred_ensemble, 0, None)))
print(f"New Ensemble Test RMSLE ({VERSION}):", ensemble_rmsle)
# Out:
# Starting CatBoost training...
# CatBoost Test RMSLE (v38): 0.06021179069084656
# Submission head:        id    Calories
# 0  750000   26.994362
# 1  750001  108.398871
# 2  750002   88.706049
# 3  750003  124.624074
# 4  750004   77.184430
# Submission stats: count    250000.000000
# mean         88.175968
# std          62.255702
# min           1.094434
# 25%          34.006268
# 50%          76.387600
# 75%         135.325510
# max         289.725654
# Name: Calories, dtype: float64
# Catboost Feature Importance (v38): Duration_MET_Interaction            41.327692
# Duration_Heart_Rate_Interaction     18.311058
# Duration_Body_Temp                   6.623186
# Duration_x_Age_Duration              6.429951
# Heart_Rate_Body_Temp_Interaction     4.198497
# Duration                             4.168359
# Heart_Rate                           3.171085
# Female_Duration                      1.949248
# Body_Temp_HR_Ratio                   1.657421
# HR_Ratio                             1.544641
# Sex_Heart_Rate_Interaction           1.340992
# MET_approx                           1.024159
# HR_Duration_Ratio                    0.872953
# BMR                                  0.776824
# BMR_Duration                         0.620791
# Age_Duration                         0.543205
# Duration_x_Age_BMI_Interaction       0.476710
# Body_Temp_x_Age_BMI_Interaction      0.436493
# Body_Temp_x_Age_Duration             0.374845
# Sex_BMI_std                          0.305605
# Sex                                  0.246019
# Sex_MET_approx_mean                  0.243169
# HR_Ratio_x_Age_BMI_Interaction       0.242262
# HR_Age                               0.233105
# Sex_BMI_mean                         0.201344
# Sex_Heart_Rate_var                   0.195977
# Male_Duration                        0.189448
# HR_Rest                              0.184684
# MET_approx_x_Age_BMI_Interaction     0.169934
# Age_BMI_Interaction                  0.157000
# Duration_x_Age_Young                 0.149504
# Duration_BMR_Interaction             0.128459
# Sex_MET_approx_max                   0.119205
# Sex_Duration_var                     0.117036
# Sex_BMI_var                          0.110166
# HR_Ratio_x_Age_Young                 0.109425
# HR_Ratio_x_Age_Duration              0.095592
# Sex_Duration_std                     0.082283
# Body_Temp_x_Age_Senior               0.078061
# Sex_Duration_mean                    0.074516
# Sex_Body_Temp_mean                   0.073906
# Body_Temp                            0.066463
# HR_Max                               0.058504
# MET_approx_x_Age_Young               0.056468
# Sex_MET_approx_std                   0.055751
# Sex_MET_approx_min                   0.050263
# Duration_x_BMI_Normalweight          0.049119
# Sex_Body_Temp_std                    0.047865
# Age_Young                            0.027734
# Sex_Heart_Rate_mean                  0.025408
# HR_Ratio_x_Age_Senior                0.025332
# Body_Temp_x_Age_Young                0.024991
# MET_approx_x_BMI_Overweight          0.023081
# MET_approx_x_Age_Senior              0.021827
# Age_Senior                           0.017182
# MET_approx_x_Age_Duration            0.015838
# Duration_x_Age_Senior                0.014293
# HR_Ratio_x_BMI_Overweight            0.013953
# Sex_BMI_max                          0.012100
# Sex_Body_Temp_var                    0.010417
# Heart_Rate_BMI_Interaction           0.009398
# Body_Temp_BMI_Interaction            0.004430
# BMI                                  0.002470
# Duration_x_BMI_Overweight            0.001946
# HR_Ratio_x_BMI_Normalweight          0.001910
# Body_Temp_x_BMI_Normalweight         0.001679
# MET_approx_x_BMI_Normalweight        0.001636
# Body_Temp_x_BMI_Overweight           0.001527
# MET_approx_x_Age_Middle              0.000754
# Body_Temp_x_Age_Middle               0.000697
# Sex_Heart_Rate_std                   0.000571
# Age_Middle                           0.000525
# Duration_x_Age_Middle                0.000406
# BMI_Overweight                       0.000237
# Sex_BMI_min                          0.000191
# HR_Ratio_x_Age_Middle                0.000127
# Sex_MET_approx_var                   0.000102
# BMI_Underweight                      0.000000
# BMI_Obese                            0.000000
# BMI_Normalweight                     0.000000
# Body_Temp_x_BMI_Underweight          0.000000
# HR_Ratio_x_BMI_Underweight           0.000000
# Duration_x_BMI_Underweight           0.000000
# HR_Ratio_x_BMI_Obese                 0.000000
# Duration_x_BMI_Obese                 0.000000
# Body_Temp_x_BMI_Obese                0.000000
# Sex_Heart_Rate_min                   0.000000
# Sex_Heart_Rate_max                   0.000000
# MET_approx_x_BMI_Underweight         0.000000
# MET_approx_x_BMI_Obese               0.000000
# Sex_Body_Temp_min                    0.000000
# Sex_Body_Temp_max                    0.000000
# Sex_Duration_min                     0.000000
# Sex_Duration_max                     0.000000
# dtype: float64
# Starting XGBoost training...
# XGBoost Test RMSLE (v38): 0.06028261119206472
# XGBoost Feature Importance (v38) : Duration_MET_Interaction            0.826188
# Duration_Heart_Rate_Interaction     0.136136
# Heart_Rate_Body_Temp_Interaction    0.016082
# Sex                                 0.003865
# Body_Temp_HR_Ratio                  0.002920
# Sex_Heart_Rate_Interaction          0.002754
# Female_Duration                     0.002642
# HR_Ratio                            0.002276
# Male_Duration                       0.001665
# Duration_x_Age_Duration             0.000915
# HR_Ratio_x_Age_Duration             0.000809
# MET_approx                          0.000477
# Heart_Rate                          0.000474
# MET_approx_x_BMI_Overweight         0.000408
# Body_Temp_x_Age_Duration            0.000251
# HR_Age                              0.000224
# MET_approx_x_Age_Senior             0.000172
# BMR                                 0.000166
# HR_Ratio_x_Age_Young                0.000123
# Duration_x_Age_Young                0.000103
# Body_Temp                           0.000088
# HR_Rest                             0.000083
# Age_Middle                          0.000074
# MET_approx_x_Age_BMI_Interaction    0.000072
# MET_approx_x_Age_Young              0.000068
# MET_approx_x_Age_Duration           0.000068
# HR_Max                              0.000067
# Duration_x_Age_BMI_Interaction      0.000064
# BMR_Duration                        0.000059
# Body_Temp_x_Age_Senior              0.000059
# Age_Duration                        0.000058
# HR_Ratio_x_Age_BMI_Interaction      0.000051
# Body_Temp_x_Age_BMI_Interaction     0.000050
# Age_BMI_Interaction                 0.000047
# Heart_Rate_BMI_Interaction          0.000040
# Duration_x_Age_Senior               0.000040
# Body_Temp_x_Age_Young               0.000036
# Duration_x_BMI_Overweight           0.000034
# HR_Duration_Ratio                   0.000027
# BMI                                 0.000024
# Duration_x_BMI_Normalweight         0.000024
# MET_approx_x_Age_Middle             0.000023
# Duration_Body_Temp                  0.000023
# HR_Ratio_x_BMI_Normalweight         0.000022
# HR_Ratio_x_BMI_Overweight           0.000021
# Body_Temp_x_BMI_Overweight          0.000018
# MET_approx_x_BMI_Normalweight       0.000017
# Body_Temp_BMI_Interaction           0.000015
# Duration                            0.000015
# Body_Temp_x_BMI_Normalweight        0.000015
# Duration_x_Age_Middle               0.000014
# Body_Temp_x_Age_Middle              0.000014
# HR_Ratio_x_Age_Senior               0.000012
# HR_Ratio_x_Age_Middle               0.000010
# BMI_Overweight                      0.000000
# BMI_Obese                           0.000000
# BMI_Underweight                     0.000000
# BMI_Normalweight                    0.000000
# Age_Young                           0.000000
# Age_Senior                          0.000000
# Duration_BMR_Interaction            0.000000
# Duration_x_BMI_Underweight          0.000000
# Body_Temp_x_BMI_Underweight         0.000000
# HR_Ratio_x_BMI_Obese                0.000000
# Duration_x_BMI_Obese                0.000000
# HR_Ratio_x_BMI_Underweight          0.000000
# MET_approx_x_BMI_Underweight        0.000000
# Body_Temp_x_BMI_Obese               0.000000
# MET_approx_x_BMI_Obese              0.000000
# Sex_BMI_min                         0.000000
# Sex_BMI_max                         0.000000
# Sex_BMI_mean                        0.000000
# Sex_BMI_std                         0.000000
# Sex_BMI_var                         0.000000
# Sex_Heart_Rate_min                  0.000000
# Sex_Heart_Rate_max                  0.000000
# Sex_Heart_Rate_mean                 0.000000
# Sex_Heart_Rate_std                  0.000000
# Sex_Heart_Rate_var                  0.000000
# Sex_Body_Temp_min                   0.000000
# Sex_Body_Temp_max                   0.000000
# Sex_Body_Temp_mean                  0.000000
# Sex_Body_Temp_std                   0.000000
# Sex_Body_Temp_var                   0.000000
# Sex_MET_approx_min                  0.000000
# Sex_MET_approx_max                  0.000000
# Sex_MET_approx_mean                 0.000000
# Sex_MET_approx_std                  0.000000
# Sex_MET_approx_var                  0.000000
# Sex_Duration_min                    0.000000
# Sex_Duration_max                    0.000000
# Sex_Duration_mean                   0.000000
# Sex_Duration_std                    0.000000
# Sex_Duration_var                    0.000000
# dtype: float32
# Starting LightGBM training...
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.099068 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9895
# [LightGBM] [Info] Number of data points in the train set: 600000, number of used features: 88
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Start training from score 4.141163
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's l2: 0.00387543
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# LightGBM Test RMSLE (v38): 0.06225296935819417
# LightGBM Feature Importance (v38): BMR                                 931
# Duration_MET_Interaction            806
# Heart_Rate_Body_Temp_Interaction    586
# Female_Duration                     410
# HR_Ratio                            333
# Body_Temp_HR_Ratio                  295
# Male_Duration                       278
# Sex_Heart_Rate_Interaction          247
# HR_Rest                             245
# Heart_Rate                          244
# MET_approx                          238
# Duration_Heart_Rate_Interaction     199
# MET_approx_x_BMI_Overweight         150
# HR_Age                               85
# Sex                                  72
# Duration_x_Age_Duration              71
# MET_approx_x_Age_Senior              66
# HR_Ratio_x_Age_Duration              57
# BMR_Duration                         56
# Body_Temp                            46
# HR_Max                               44
# MET_approx_x_Age_BMI_Interaction     38
# Duration_x_Age_Young                 37
# Heart_Rate_BMI_Interaction           37
# HR_Duration_Ratio                    34
# Body_Temp_x_Age_BMI_Interaction      32
# HR_Ratio_x_Age_BMI_Interaction       28
# Age_BMI_Interaction                  26
# HR_Ratio_x_Age_Young                 26
# HR_Ratio_x_BMI_Normalweight          25
# Duration_x_BMI_Overweight            22
# MET_approx_x_Age_Duration            22
# Duration_x_Age_BMI_Interaction       18
# Duration_x_Age_Senior                13
# Body_Temp_x_Age_Young                11
# Duration_Body_Temp                   10
# Duration_x_BMI_Normalweight           9
# Body_Temp_x_Age_Duration              9
# HR_Ratio_x_Age_Senior                 8
# Body_Temp_x_Age_Senior                8
# Body_Temp_BMI_Interaction             5
# Age_Duration                          5
# HR_Ratio_x_BMI_Overweight             5
# MET_approx_x_BMI_Normalweight         3
# MET_approx_x_Age_Middle               2
# MET_approx_x_Age_Young                2
# Duration_x_Age_Middle                 2
# Body_Temp_x_BMI_Overweight            2
# Body_Temp_x_BMI_Normalweight          1
# Body_Temp_x_Age_Middle                1
# BMI_Overweight                        0
# Age_Senior                            0
# BMI_Underweight                       0
# BMI_Normalweight                      0
# Duration                              0
# BMI_Obese                             0
# BMI                                   0
# Age_Young                             0
# Age_Middle                            0
# Duration_BMR_Interaction              0
# HR_Ratio_x_Age_Middle                 0
# Duration_x_BMI_Underweight            0
# Body_Temp_x_BMI_Underweight           0
# HR_Ratio_x_BMI_Obese                  0
# Duration_x_BMI_Obese                  0
# HR_Ratio_x_BMI_Underweight            0
# MET_approx_x_BMI_Underweight          0
# Body_Temp_x_BMI_Obese                 0
# MET_approx_x_BMI_Obese                0
# Sex_BMI_min                           0
# Sex_BMI_max                           0
# Sex_BMI_mean                          0
# Sex_BMI_std                           0
# Sex_BMI_var                           0
# Sex_Heart_Rate_min                    0
# Sex_Heart_Rate_max                    0
# Sex_Heart_Rate_mean                   0
# Sex_Heart_Rate_std                    0
# Sex_Heart_Rate_var                    0
# Sex_Body_Temp_min                     0
# Sex_Body_Temp_max                     0
# Sex_Body_Temp_mean                    0
# Sex_Body_Temp_std                     0
# Sex_Body_Temp_var                     0
# Sex_MET_approx_min                    0
# Sex_MET_approx_max                    0
# Sex_MET_approx_mean                   0
# Sex_MET_approx_std                    0
# Sex_MET_approx_var                    0
# Sex_Duration_min                      0
# Sex_Duration_max                      0
# Sex_Duration_mean                     0
# Sex_Duration_std                      0
# Sex_Duration_var                      0
# dtype: int32
# New ensemble submission head:        id    Calories
# 0  750000   27.152057
# 1  750001  108.027194
# 2  750002   88.611160
# 3  750003  124.764817
# 4  750004   77.105215
# New ensemble Calories stats : count    250000.000000
# mean         88.117491
# std          62.156934
# min           1.128875
# 25%          34.028313
# 50%          76.349420
# 75%         135.270666
# max         283.956605
# Name: Calories, dtype: float64
# Starting CV...
# XGBoost 5-Fold CV RMSLE (v38): 0.060796 ± 0.001280
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019209 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9817
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 78
# [LightGBM] [Info] Start training from score 4.136164
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031691 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9816
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 78
# [LightGBM] [Info] Start training from score 4.139194
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020566 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9816
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 78
# [LightGBM] [Info] Start training from score 4.139783
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019543 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9816
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 78
# [LightGBM] [Info] Start training from score 4.137660
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9817
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 78
# [LightGBM] [Info] Start training from score 4.138292
# [LightGBM] [Warning] Unknown parameter: silent
# LightGBM 5-Fold CV RMSLE (v38): 0.063118 ± 0.001734
# CatBoost 5-Fold CV RMSLE (v38): 0.060514 ± 0.001152
# Finished CV...
# New Ensemble Test RMSLE (v38): 0.06003088148286372

# %% [markdown]
# # Tuning

# %%
def finetune_xgboost():
    X_train_sub, _, y_train_sub, _ = train_test_split(X, y_log, train_size=0.1, random_state=42)
    parameters = {
        'objective': ['reg:squaredlogerror'],
        'learning_rate': [0.05, 0.1, 0.3],
        'n_estimators': [600],
        'reg_alpha': [0.5, 1, 2],
        'reg_lambda': [0, 1, 2],
        'gamma': [0, 1, 2],
        'max_depth': [6, 8, 10]
    }
    xgb_model = XGBRegressor(device='cuda', random_state=42, n_jobs=-1, verbosity=2)
    grid = RandomizedSearchCV(xgb_model, parameters, n_iter=20, cv=3, scoring=rmsle_fn, random_state=42)
    print("Starting XGBoost tuning...")
    grid.fit(X_train_sub, y_train_sub)
    print("Finished XGBoost tuning...")
    print(f"Best XGBoost parameters ({VERSION}):", grid.best_params_)
    print(f"Best XGBoost CV RMSLE ({VERSION}):", -grid.best_score_)
    return grid

# Tune CatBoost
def finetune_catboost():
    X_train_sub, _, y_train_sub, _ = train_test_split(X, y_log, train_size=0.1, random_state=42)
    param_grid = {
        'iterations': [400, 600, 800],
        'depth': [9, 11, 13],
        'learning_rate': [0.03, 0.05, 0.07],
        'l2_leaf_reg': [3, 5, 7],
        'bagging_temperature': [0, 0.5, 1.0]
    }
    cb = CatBoostRegressor(random_seed=42, verbose=0, task_type='GPU', devices='0')
    grid = RandomizedSearchCV(cb, param_grid, n_iter=10, cv=3, scoring=rmsle_fn, random_state=42)
    print("Starting CatBoost tuning...")
    grid.fit(X_train_sub, y_train_sub, **{'early_stopping_rounds': 10})
    print("Finished CatBoost tuning...")
    print(f"Best CatBoost parameters ({VERSION}):", grid.best_params_)
    print(f"Best CatBoost CV RMSLE ({VERSION}):", -grid.best_score_)
    return grid

# Tune LightGBM
def finetune_lightgbm():
  X_train_sub, _, y_train_sub, _ = train_test_split(X, y_log, train_size=0.2, random_state=42)
  param_grid = {
      'num_leaves': [60, 90, 120, 150],
      'max_depth': [15, 20, 25, 30],
      'learning_rate': [0.01, 0.03, 0.05],
      'reg_alpha': [1.0, 1.5, 2.0],
      'reg_lambda': [0.3, 0.5, 0.7],
      'min_child_samples': [10, 20, 30]
  }
  lgb_model = lgb.LGBMRegressor(n_estimators=300, device='gpu', random_state=42, force_row_wise=True)
  grid = RandomizedSearchCV(lgb_model, param_grid, n_iter=10, cv=3, scoring=rmsle_fn, random_state=42)
  print("Starting LightGBM tuning...")
  grid.fit(X_train_sub, y_train_sub)
  print("Finished LightGBM tuning...")
  print(f"Best LightGBM parameters ({VERSION}):", grid.best_params_)
  print(f"Best LightGBM CV RMSLE ({VERSION}):", -grid.best_score_)
  return grid

if not cb_grid:
  cb_grid = finetune_catboost()
  BEST_CB_PARAMS = cb_grid.best_params_

if not xgb_grid:
  xgb_grid = finetune_xgboost()
  BEST_XGB_PARAMS = xgb_grid.best_params_

if not lgb_grid:
  lgb_grid = finetune_lightgbm()
  BEST_LGBM_PARAMS = lgb_grid.best_params_

# %%
# Manual ensemble weighting
weights = {'xgboost': 0.35, 'lightgbm': 0.30, 'catboost': 0.35}
print(f"Manual Ensemble Weights ({VERSION}):", weights)

# Generate ensemble submission using manual weights
X_test_final = test_data.drop(['id'], axis=1)
y_pred_final_xgb_log = xgb_model.predict(X_test_final)
y_pred_final_xgb = np.expm1(y_pred_final_xgb_log)
y_pred_final_lgb_log = lgb_model.predict(X_test_final)
y_pred_final_lgb = np.expm1(y_pred_final_lgb_log)
y_pred_final_cb_log = cb_model.predict(X_test_final)
y_pred_final_cb = np.expm1(y_pred_final_cb_log)
y_pred_final_ensemble = weights['lightgbm'] * y_pred_final_lgb + weights['xgboost'] * y_pred_final_xgb + weights['catboost'] * y_pred_final_cb
submission_ensemble = pd.DataFrame({'id': test_data['id'], 'Calories': np.clip(y_pred_final_ensemble, 0, None)})
submission_ensemble.to_csv(f'submission_optimized_ensemble_{VERSION}.csv', index=False)

# Tune XGBoost meta-learner
def tune_meta_learner():
    meta_X = np.column_stack((y_pred_xgb_log, y_pred_lgb_log, y_pred_cb_log))
    param_grid = {
        'n_estimators': [50, 100, 150],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.05, 0.1],
        'reg_alpha': [0, 0.1],
        'reg_lambda': [0, 0.1]
    }
    meta_model = XGBRegressor(random_state=42, device='gpu')
    grid = RandomizedSearchCV(meta_model, param_grid, n_iter=5, cv=5, scoring=rmsle_fn)
    print("Starting meta-learner tuning...")
    grid.fit(meta_X, y_test_log)
    print("Finished meta-learner tuning...")
    print(f"Best Meta-Learner Parameters ({VERSION}):", grid.best_params_)
    return grid.best_estimator_

meta_model_xgb = tune_meta_learner()

# Stacking with tuned XGBoost meta-learner
meta_X = np.column_stack((y_pred_xgb_log, y_pred_lgb_log, y_pred_cb_log))
meta_model_xgb.fit(meta_X, y_test_log)
meta_X_final = np.column_stack((y_pred_final_xgb_log, y_pred_final_lgb_log, y_pred_final_cb_log))
y_pred_final_ensemble_stack_xgb = meta_model_xgb.predict(meta_X_final)
y_pred_final_ensemble_stack_xgb = np.expm1(y_pred_final_ensemble_stack_xgb)
submission_stack_xgb = pd.DataFrame({'id': test_data['id'], 'Calories': np.clip(y_pred_final_ensemble_stack_xgb, 0, None)})
submission_stack_xgb.to_csv(f'submission_stacking_xgb_tuned_{VERSION}.csv', index=False)

# Neural network meta-learner
def create_nn_meta_learner():
    model = Sequential([
        Input(shape=(3,)),
        Dense(128, activation='relu'),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    return model

print("Starting neural network training...")
meta_model_nn = create_nn_meta_learner()
meta_X = np.column_stack((y_pred_xgb_log, y_pred_lgb_log, y_pred_cb_log))
meta_model_nn.fit(meta_X, y_test_log, epochs=50, batch_size=512, verbose=0)
print("Finished neural network training...")
y_pred_final_ensemble_stack_nn = meta_model_nn.predict(np.column_stack((y_pred_final_xgb_log, y_pred_final_lgb_log, y_pred_final_cb_log)), verbose=0)
y_pred_final_ensemble_stack_nn = np.expm1(y_pred_final_ensemble_stack_nn.flatten())
submission_stack_nn = pd.DataFrame({'id': test_data['id'], 'Calories': np.clip(y_pred_final_ensemble_stack_nn, 0, None)})
submission_stack_nn.to_csv(f'submission_stacking_nn_{VERSION}.csv', index=False)

# Combine ensemble and stacking predictions
y_pred_final_combined = 0.7 * y_pred_final_ensemble + 0.3 * y_pred_final_ensemble_stack_nn
submission_combined = pd.DataFrame({'id': test_data['id'], 'Calories': np.clip(y_pred_final_combined, 0, None)})
submission_combined.to_csv(f'submission_combined_ensemble_stack_{VERSION}.csv', index=False)

# Feature importance
importance_xgb = pd.Series(xgb_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
importance_lgb = pd.Series(lgb_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
print(f"XGBoost Feature Importance ({VERSION}):\n", importance_xgb)
print(f"LightGBM Feature Importance ({VERSION}):\n", importance_lgb)

# Residual plot
y_pred_ensemble = weights['lightgbm'] * y_pred_lgb + weights['xgboost'] * y_pred_xgb + weights['catboost'] * y_pred_cb
residuals = y_test - y_pred_ensemble
plt.scatter(y_test, residuals, alpha=0.5)
plt.xlabel('True Calories')
plt.ylabel('Residuals')
plt.axhline(0, color='red', linestyle='--')
plt.savefig(f'residuals_{VERSION}.png')
plt.close()
# Out:
# Starting CV...
# XGBoost 5-Fold CV RMSLE (v32): 0.061711 ± 0.001715
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 5157
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 31
# [LightGBM] [Info] Using GPU Device: NVIDIA L4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 30 dense feature groups (3.66 MB) transferred to GPU in 0.003600 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 4.136164
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 5158
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 31
# [LightGBM] [Info] Using GPU Device: NVIDIA L4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 30 dense feature groups (3.66 MB) transferred to GPU in 0.003967 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 4.139194
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 5156
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 31
# [LightGBM] [Info] Using GPU Device: NVIDIA L4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 30 dense feature groups (3.66 MB) transferred to GPU in 0.003595 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 4.139783
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 5159
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 31
# [LightGBM] [Info] Using GPU Device: NVIDIA L4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 30 dense feature groups (3.66 MB) transferred to GPU in 0.003477 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 4.137660
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 5157
# [LightGBM] [Info] Number of data points in the train set: 120000, number of used features: 31
# [LightGBM] [Info] Using GPU Device: NVIDIA L4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 30 dense feature groups (3.66 MB) transferred to GPU in 0.003465 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 4.138292
# LightGBM 5-Fold CV RMSLE (v32): 0.060995 ± 0.001496
# 0:	learn: 0.9183226	total: 5.43ms	remaining: 2.17s
# 1:	learn: 0.8742348	total: 9.4ms	remaining: 1.87s
# 2:	learn: 0.8323638	total: 13.3ms	remaining: 1.76s
# 3:	learn: 0.7924473	total: 17.1ms	remaining: 1.7s
# 4:	learn: 0.7543822	total: 21ms	remaining: 1.66s
# 5:	learn: 0.7183362	total: 24.9ms	remaining: 1.64s
# 6:	learn: 0.6841842	total: 28.7ms	remaining: 1.61s
# 7:	learn: 0.6518229	total: 32.6ms	remaining: 1.6s
# 8:	learn: 0.6208659	total: 36.6ms	remaining: 1.59s
# 9:	learn: 0.5914140	total: 40.5ms	remaining: 1.58s
# 10:	learn: 0.5636188	total: 44.5ms	remaining: 1.57s
# 11:	learn: 0.5369742	total: 48.4ms	remaining: 1.56s
# 12:	learn: 0.5117735	total: 52.3ms	remaining: 1.56s
# 13:	learn: 0.4876575	total: 56.1ms	remaining: 1.55s
# 14:	learn: 0.4648799	total: 60.1ms	remaining: 1.54s
# 62:	learn: 0.0806608	total: 247ms	remaining: 1.32s
# 63:	learn: 0.0793292	total: 251ms	remaining: 1.32s
# 64:	learn: 0.0780910	total: 255ms	remaining: 1.31s
# 65:	learn: 0.0769372	total: 259ms	remaining: 1.31s
# 66:	learn: 0.0758715	total: 263ms	remaining: 1.31s
# 67:	learn: 0.0748266	total: 267ms	remaining: 1.3s
# 68:	learn: 0.0738664	total: 271ms	remaining: 1.3s
# 69:	learn: 0.0729698	total: 275ms	remaining: 1.3s
# 70:	learn: 0.0721278	total: 279ms	remaining: 1.29s
# 71:	learn: 0.0713684	total: 283ms	remaining: 1.29s
# 72:	learn: 0.0706334	total: 287ms	remaining: 1.28s
# 73:	learn: 0.0699498	total: 291ms	remaining: 1.28s
# 74:	learn: 0.0693345	total: 295ms	remaining: 1.28s
# 75:	learn: 0.0687419	total: 298ms	remaining: 1.27s
# 76:	learn: 0.0681934	total: 302ms	remaining: 1.27s
# 77:	learn: 0.0677045	total: 306ms	remaining: 1.26s
# 78:	learn: 0.0672274	total: 310ms	remaining: 1.26s
# 79:	learn: 0.0667670	total: 314ms	remaining: 1.26s
# 80:	learn: 0.0663438	total: 318ms	remaining: 1.25s
# 81:	learn: 0.0659632	total: 322ms	remaining: 1.25s
# 82:	learn: 0.0655902	total: 326ms	remaining: 1.24s
# 83:	learn: 0.0652498	total: 330ms	remaining: 1.24s
# 84:	learn: 0.0649392	total: 334ms	remaining: 1.24s
# 85:	learn: 0.0646584	total: 338ms	remaining: 1.23s
# 86:	learn: 0.0644017	total: 341ms	remaining: 1.23s
# 87:	learn: 0.0641389	total: 345ms	remaining: 1.22s
# 88:	learn: 0.0638995	total: 349ms	remaining: 1.22s
# 89:	learn: 0.0636860	total: 353ms	remaining: 1.22s
# 90:	learn: 0.0634871	total: 357ms	remaining: 1.21s
# 91:	learn: 0.0632926	total: 361ms	remaining: 1.21s
# 92:	learn: 0.0630977	total: 365ms	remaining: 1.2s
# 93:	learn: 0.0629119	total: 369ms	remaining: 1.2s
# 94:	learn: 0.0627574	total: 373ms	remaining: 1.2s
# 95:	learn: 0.0626127	total: 377ms	remaining: 1.19s
# 96:	learn: 0.0624481	total: 381ms	remaining: 1.19s
# 97:	learn: 0.0623208	total: 385ms	remaining: 1.19s
# 98:	learn: 0.0621795	total: 389ms	remaining: 1.18s
# 99:	learn: 0.0620504	total: 393ms	remaining: 1.18s
# 100:	learn: 0.0619373	total: 397ms	remaining: 1.17s
# 101:	learn: 0.0618191	total: 401ms	remaining: 1.17s
# 102:	learn: 0.0617170	total: 405ms	remaining: 1.17s
# 103:	learn: 0.0616193	total: 409ms	remaining: 1.16s
# 104:	learn: 0.0615295	total: 413ms	remaining: 1.16s
# 105:	learn: 0.0614447	total: 416ms	remaining: 1.16s
# 106:	learn: 0.0613620	total: 420ms	remaining: 1.15s
# 107:	learn: 0.0612906	total: 424ms	remaining: 1.15s
# 108:	learn: 0.0612242	total: 428ms	remaining: 1.14s
# 109:	learn: 0.0611524	total: 432ms	remaining: 1.14s
# 399:	learn: 0.0561012	total: 1.6s	remaining: 0us
# 0:	learn: 0.9171193	total: 4.67ms	remaining: 1.86s
# 1:	learn: 0.8730794	total: 8.58ms	remaining: 1.71s
# 2:	learn: 0.8312531	total: 12.4ms	remaining: 1.65s
# 3:	learn: 0.7913764	total: 16.4ms	remaining: 1.62s
# 4:	learn: 0.7533563	total: 20.3ms	remaining: 1.61s
# 5:	learn: 0.7173899	total: 24.3ms	remaining: 1.59s
# 6:	learn: 0.6831837	total: 28.1ms	remaining: 1.58s
# 7:	learn: 0.6506298	total: 32.1ms	remaining: 1.57s
# 8:	learn: 0.6196949	total: 36ms	remaining: 1.56s
# 9:	learn: 0.5902663	total: 40ms	remaining: 1.56s
# 10:	learn: 0.5622412	total: 43.9ms	remaining: 1.55s
# 11:	learn: 0.5358205	total: 47.8ms	remaining: 1.55s
# 12:	learn: 0.5107483	total: 51.8ms	remaining: 1.54s
# 13:	learn: 0.4867100	total: 55.7ms	remaining: 1.53s
# 14:	learn: 0.4638873	total: 59.6ms	remaining: 1.53s
# 15:	learn: 0.4423340	total: 63.5ms	remaining: 1.52s
# 16:	learn: 0.4217039	total: 67.2ms	remaining: 1.51s
# 17:	learn: 0.4023114	total: 71.1ms	remaining: 1.51s
# 18:	learn: 0.3838229	total: 74.9ms	remaining: 1.5s
# 19:	learn: 0.3662047	total: 78.7ms	remaining: 1.49s
# 20:	learn: 0.3495496	total: 82.5ms	remaining: 1.49s
# 21:	learn: 0.3337556	total: 86.4ms	remaining: 1.48s
# 22:	learn: 0.3187563	total: 90.4ms	remaining: 1.48s
# 23:	learn: 0.3044654	total: 94.2ms	remaining: 1.48s
# 24:	learn: 0.2907767	total: 98ms	remaining: 1.47s
# 25:	learn: 0.2778615	total: 102ms	remaining: 1.46s
# 26:	learn: 0.2656087	total: 106ms	remaining: 1.46s
# 27:	learn: 0.2540011	total: 110ms	remaining: 1.46s
# 28:	learn: 0.2429603	total: 114ms	remaining: 1.45s
# 29:	learn: 0.2325124	total: 117ms	remaining: 1.45s
# 30:	learn: 0.2226953	total: 121ms	remaining: 1.44s
# 31:	learn: 0.2132085	total: 125ms	remaining: 1.44s
# 32:	learn: 0.2042278	total: 129ms	remaining: 1.44s
# 33:	learn: 0.1957962	total: 133ms	remaining: 1.43s
# 34:	learn: 0.1878377	total: 137ms	remaining: 1.43s
# 35:	learn: 0.1802514	total: 141ms	remaining: 1.43s
# 36:	learn: 0.1731173	total: 145ms	remaining: 1.42s
# 37:	learn: 0.1663300	total: 149ms	remaining: 1.42s
# 38:	learn: 0.1599011	total: 153ms	remaining: 1.41s
# 39:	learn: 0.1537835	total: 156ms	remaining: 1.41s
# 40:	learn: 0.1480796	total: 160ms	remaining: 1.4s
# 41:	learn: 0.1427241	total: 164ms	remaining: 1.4s
# 42:	learn: 0.1376219	total: 168ms	remaining: 1.39s
# 43:	learn: 0.1328081	total: 172ms	remaining: 1.39s
# 44:	learn: 0.1283029	total: 176ms	remaining: 1.39s
# 93:	learn: 0.0627666	total: 368ms	remaining: 1.2s
# 94:	learn: 0.0626055	total: 372ms	remaining: 1.19s
# 95:	learn: 0.0624693	total: 375ms	remaining: 1.19s
# 96:	learn: 0.0623284	total: 379ms	remaining: 1.18s
# 97:	learn: 0.0622032	total: 383ms	remaining: 1.18s
# 98:	learn: 0.0620627	total: 387ms	remaining: 1.18s
# 99:	learn: 0.0619435	total: 391ms	remaining: 1.17s
# 100:	learn: 0.0618411	total: 395ms	remaining: 1.17s
# 101:	learn: 0.0617262	total: 399ms	remaining: 1.17s
# 102:	learn: 0.0616292	total: 403ms	remaining: 1.16s
# 103:	learn: 0.0615302	total: 407ms	remaining: 1.16s
# 104:	learn: 0.0614449	total: 411ms	remaining: 1.15s
# 105:	learn: 0.0613618	total: 415ms	remaining: 1.15s
# 106:	learn: 0.0612889	total: 419ms	remaining: 1.15s
# 107:	learn: 0.0612083	total: 423ms	remaining: 1.14s
# 108:	learn: 0.0611318	total: 427ms	remaining: 1.14s
# 109:	learn: 0.0610692	total: 430ms	remaining: 1.13s
# 110:	learn: 0.0609987	total: 434ms	remaining: 1.13s
# 111:	learn: 0.0609354	total: 438ms	remaining: 1.13s
# 112:	learn: 0.0608619	total: 442ms	remaining: 1.12s
# 113:	learn: 0.0607850	total: 446ms	remaining: 1.12s
# 114:	learn: 0.0607293	total: 450ms	remaining: 1.11s
# 115:	learn: 0.0606765	total: 454ms	remaining: 1.11s
# 116:	learn: 0.0606298	total: 458ms	remaining: 1.11s
# 117:	learn: 0.0605714	total: 462ms	remaining: 1.1s
# 118:	learn: 0.0605266	total: 465ms	remaining: 1.1s
# 119:	learn: 0.0604777	total: 469ms	remaining: 1.09s
# 120:	learn: 0.0604237	total: 473ms	remaining: 1.09s
# 121:	learn: 0.0603693	total: 477ms	remaining: 1.09s
# 122:	learn: 0.0603347	total: 481ms	remaining: 1.08s
# 123:	learn: 0.0602944	total: 485ms	remaining: 1.08s
# 124:	learn: 0.0602591	total: 489ms	remaining: 1.08s
# 125:	learn: 0.0602152	total: 493ms	remaining: 1.07s
# 126:	learn: 0.0601736	total: 497ms	remaining: 1.07s
# 127:	learn: 0.0601439	total: 501ms	remaining: 1.06s
# 128:	learn: 0.0601026	total: 506ms	remaining: 1.06s
# 129:	learn: 0.0600643	total: 510ms	remaining: 1.06s
# 130:	learn: 0.0600261	total: 514ms	remaining: 1.05s
# 131:	learn: 0.0599906	total: 518ms	remaining: 1.05s
# 132:	learn: 0.0599569	total: 522ms	remaining: 1.05s
# 133:	learn: 0.0599152	total: 526ms	remaining: 1.04s
# 134:	learn: 0.0598862	total: 530ms	remaining: 1.04s
# 135:	learn: 0.0598555	total: 534ms	remaining: 1.03s
# 136:	learn: 0.0598273	total: 538ms	remaining: 1.03s
# 137:	learn: 0.0597986	total: 542ms	remaining: 1.03s
# 138:	learn: 0.0597720	total: 546ms	remaining: 1.02s
# 139:	learn: 0.0597363	total: 550ms	remaining: 1.02s
# 140:	learn: 0.0597072	total: 554ms	remaining: 1.02s
# 288:	learn: 0.0573826	total: 1.15s	remaining: 440ms
# 289:	learn: 0.0573748	total: 1.15s	remaining: 436ms
# 290:	learn: 0.0573679	total: 1.15s	remaining: 432ms
# 291:	learn: 0.0573589	total: 1.16s	remaining: 428ms
# 292:	learn: 0.0573475	total: 1.16s	remaining: 424ms
# 293:	learn: 0.0573400	total: 1.17s	remaining: 420ms
# 294:	learn: 0.0573308	total: 1.17s	remaining: 416ms
# 295:	learn: 0.0573129	total: 1.17s	remaining: 412ms
# 296:	learn: 0.0573064	total: 1.18s	remaining: 409ms
# 297:	learn: 0.0572963	total: 1.18s	remaining: 405ms
# 298:	learn: 0.0572818	total: 1.19s	remaining: 401ms
# 299:	learn: 0.0572704	total: 1.19s	remaining: 397ms
# 300:	learn: 0.0572566	total: 1.19s	remaining: 393ms
# 301:	learn: 0.0572486	total: 1.2s	remaining: 389ms
# 302:	learn: 0.0572296	total: 1.2s	remaining: 385ms
# 303:	learn: 0.0572203	total: 1.21s	remaining: 381ms
# 304:	learn: 0.0572147	total: 1.21s	remaining: 377ms
# 305:	learn: 0.0572062	total: 1.21s	remaining: 373ms
# 306:	learn: 0.0571894	total: 1.22s	remaining: 369ms
# 307:	learn: 0.0571744	total: 1.22s	remaining: 365ms
# 308:	learn: 0.0571600	total: 1.23s	remaining: 361ms
# 309:	learn: 0.0571507	total: 1.23s	remaining: 357ms
# 310:	learn: 0.0571421	total: 1.23s	remaining: 353ms
# 311:	learn: 0.0571345	total: 1.24s	remaining: 349ms
# 312:	learn: 0.0571203	total: 1.24s	remaining: 345ms
# 313:	learn: 0.0571091	total: 1.25s	remaining: 341ms
# 314:	learn: 0.0571032	total: 1.25s	remaining: 337ms
# 315:	learn: 0.0570917	total: 1.25s	remaining: 333ms
# 316:	learn: 0.0570830	total: 1.26s	remaining: 329ms
# 317:	learn: 0.0570705	total: 1.26s	remaining: 325ms
# 318:	learn: 0.0570648	total: 1.26s	remaining: 321ms
# 319:	learn: 0.0570566	total: 1.27s	remaining: 317ms
# 320:	learn: 0.0570507	total: 1.27s	remaining: 313ms
# 321:	learn: 0.0570318	total: 1.28s	remaining: 309ms
# 322:	learn: 0.0570179	total: 1.28s	remaining: 306ms
# 323:	learn: 0.0570077	total: 1.28s	remaining: 302ms
# 324:	learn: 0.0569953	total: 1.29s	remaining: 298ms
# 325:	learn: 0.0569860	total: 1.29s	remaining: 294ms
# 326:	learn: 0.0569803	total: 1.3s	remaining: 290ms
# 327:	learn: 0.0569660	total: 1.3s	remaining: 286ms
# 328:	learn: 0.0569566	total: 1.3s	remaining: 282ms
# 329:	learn: 0.0569456	total: 1.31s	remaining: 278ms
# 330:	learn: 0.0569389	total: 1.31s	remaining: 274ms
# 331:	learn: 0.0569251	total: 1.32s	remaining: 270ms
# 332:	learn: 0.0569133	total: 1.32s	remaining: 266ms
# 333:	learn: 0.0569003	total: 1.32s	remaining: 262ms
# 334:	learn: 0.0568918	total: 1.33s	remaining: 258ms
# 335:	learn: 0.0568856	total: 1.33s	remaining: 254ms
# 383:	learn: 0.0564728	total: 1.52s	remaining: 63.4ms
# 384:	learn: 0.0564651	total: 1.53s	remaining: 59.5ms
# 385:	learn: 0.0564472	total: 1.53s	remaining: 55.5ms
# 386:	learn: 0.0564350	total: 1.53s	remaining: 51.5ms
# 387:	learn: 0.0564187	total: 1.54s	remaining: 47.6ms
# 388:	learn: 0.0564153	total: 1.54s	remaining: 43.6ms
# 389:	learn: 0.0564035	total: 1.54s	remaining: 39.6ms
# 390:	learn: 0.0563944	total: 1.55s	remaining: 35.7ms
# 391:	learn: 0.0563852	total: 1.55s	remaining: 31.7ms
# 392:	learn: 0.0563784	total: 1.56s	remaining: 27.8ms
# 393:	learn: 0.0563714	total: 1.56s	remaining: 23.8ms
# 394:	learn: 0.0563632	total: 1.57s	remaining: 19.8ms
# 395:	learn: 0.0563445	total: 1.57s	remaining: 15.9ms
# 396:	learn: 0.0563363	total: 1.57s	remaining: 11.9ms
# 397:	learn: 0.0563259	total: 1.58s	remaining: 7.93ms
# 398:	learn: 0.0563144	total: 1.58s	remaining: 3.97ms
# 399:	learn: 0.0562989	total: 1.59s	remaining: 0us
# 0:	learn: 0.9149705	total: 4.74ms	remaining: 1.89s
# 1:	learn: 0.8712443	total: 8.78ms	remaining: 1.75s
# 2:	learn: 0.8296838	total: 12.7ms	remaining: 1.68s
# 3:	learn: 0.7898726	total: 16.6ms	remaining: 1.64s
# 4:	learn: 0.7519272	total: 20.5ms	remaining: 1.62s
# 5:	learn: 0.7159192	total: 24.3ms	remaining: 1.59s
# 6:	learn: 0.6818371	total: 28.2ms	remaining: 1.58s
# 7:	learn: 0.6493928	total: 32.1ms	remaining: 1.57s
# 8:	learn: 0.6185306	total: 35.9ms	remaining: 1.56s
# 9:	learn: 0.5891562	total: 39.9ms	remaining: 1.55s
# 10:	learn: 0.5611549	total: 43.6ms	remaining: 1.54s
# 11:	learn: 0.5346649	total: 47.5ms	remaining: 1.54s
# 12:	learn: 0.5096618	total: 51.5ms	remaining: 1.53s
# 13:	learn: 0.4856442	total: 55.3ms	remaining: 1.52s
# 14:	learn: 0.4630021	total: 59.2ms	remaining: 1.52s
# 15:	learn: 0.4414062	total: 63ms	remaining: 1.51s
# 16:	learn: 0.4207568	total: 66.9ms	remaining: 1.51s
# 17:	learn: 0.4012922	total: 70.8ms	remaining: 1.5s
# 18:	learn: 0.3828462	total: 74.8ms	remaining: 1.5s
# 19:	learn: 0.3652697	total: 78.9ms	remaining: 1.5s
# 20:	learn: 0.3485948	total: 82.8ms	remaining: 1.49s
# 21:	learn: 0.3329544	total: 86.6ms	remaining: 1.49s
# 22:	learn: 0.3179019	total: 90.6ms	remaining: 1.48s
# 23:	learn: 0.3036521	total: 94.4ms	remaining: 1.48s
# 24:	learn: 0.2900629	total: 98.3ms	remaining: 1.47s
# 25:	learn: 0.2771460	total: 102ms	remaining: 1.47s
# 26:	learn: 0.2649701	total: 106ms	remaining: 1.47s
# 27:	learn: 0.2534615	total: 110ms	remaining: 1.46s
# 28:	learn: 0.2424510	total: 114ms	remaining: 1.46s
# 29:	learn: 0.2320024	total: 118ms	remaining: 1.45s
# 30:	learn: 0.2222108	total: 122ms	remaining: 1.45s
# 31:	learn: 0.2128570	total: 126ms	remaining: 1.44s
# 32:	learn: 0.2039921	total: 130ms	remaining: 1.44s
# 33:	learn: 0.1956209	total: 134ms	remaining: 1.44s
# 34:	learn: 0.1876282	total: 137ms	remaining: 1.43s
# 35:	learn: 0.1799868	total: 141ms	remaining: 1.43s
# 36:	learn: 0.1728266	total: 145ms	remaining: 1.43s
# 37:	learn: 0.1660697	total: 149ms	remaining: 1.42s
# 38:	learn: 0.1596776	total: 153ms	remaining: 1.42s
# 39:	learn: 0.1536146	total: 157ms	remaining: 1.41s
# 40:	learn: 0.1478929	total: 161ms	remaining: 1.41s
# 41:	learn: 0.1424695	total: 164ms	remaining: 1.4s
# 42:	learn: 0.1373176	total: 168ms	remaining: 1.4s
# 43:	learn: 0.1325074	total: 172ms	remaining: 1.39s
# 44:	learn: 0.1279138	total: 176ms	remaining: 1.39s
# 45:	learn: 0.1236319	total: 180ms	remaining: 1.39s
# 46:	learn: 0.1195713	total: 184ms	remaining: 1.38s
# 47:	learn: 0.1157720	total: 188ms	remaining: 1.38s
# 48:	learn: 0.1121892	total: 192ms	remaining: 1.37s
# 49:	learn: 0.1088031	total: 196ms	remaining: 1.37s
# 50:	learn: 0.1056441	total: 199ms	remaining: 1.36s
# 51:	learn: 0.1026589	total: 203ms	remaining: 1.36s
# 52:	learn: 0.0998735	total: 208ms	remaining: 1.36s
# 53:	learn: 0.0972192	total: 211ms	remaining: 1.35s
# 54:	learn: 0.0947906	total: 215ms	remaining: 1.35s
# 55:	learn: 0.0924384	total: 219ms	remaining: 1.35s
# 56:	learn: 0.0902993	total: 223ms	remaining: 1.34s
# 57:	learn: 0.0882650	total: 227ms	remaining: 1.34s
# 58:	learn: 0.0863808	total: 231ms	remaining: 1.33s
# 59:	learn: 0.0846233	total: 234ms	remaining: 1.33s
# 60:	learn: 0.0829723	total: 238ms	remaining: 1.32s
# 61:	learn: 0.0814316	total: 242ms	remaining: 1.32s
# 62:	learn: 0.0799920	total: 246ms	remaining: 1.32s
# 63:	learn: 0.0786541	total: 250ms	remaining: 1.31s
# 64:	learn: 0.0773821	total: 254ms	remaining: 1.31s
# 65:	learn: 0.0762170	total: 258ms	remaining: 1.3s
# 66:	learn: 0.0751005	total: 262ms	remaining: 1.3s
# 67:	learn: 0.0740963	total: 266ms	remaining: 1.3s
# 68:	learn: 0.0731447	total: 269ms	remaining: 1.29s
# 69:	learn: 0.0722634	total: 273ms	remaining: 1.29s
# 70:	learn: 0.0714213	total: 277ms	remaining: 1.28s
# ...
# 164:	learn: 0.0590632	total: 656ms	remaining: 935ms
# 165:	learn: 0.0590436	total: 661ms	remaining: 931ms
# 166:	learn: 0.0590236	total: 665ms	remaining: 927ms
# 167:	learn: 0.0590002	total: 669ms	remaining: 923ms
# 168:	learn: 0.0589832	total: 673ms	remaining: 919ms
# 267:	learn: 0.0574253	total: 1.07s	remaining: 528ms
# 268:	learn: 0.0574133	total: 1.07s	remaining: 524ms
# 269:	learn: 0.0574001	total: 1.08s	remaining: 520ms
# 270:	learn: 0.0573894	total: 1.08s	remaining: 516ms
# 271:	learn: 0.0573766	total: 1.09s	remaining: 512ms
# 272:	learn: 0.0573634	total: 1.09s	remaining: 508ms
# 273:	learn: 0.0573499	total: 1.09s	remaining: 504ms
# 274:	learn: 0.0573272	total: 1.1s	remaining: 500ms
# 275:	learn: 0.0573159	total: 1.1s	remaining: 496ms
# 276:	learn: 0.0573035	total: 1.11s	remaining: 492ms
# 277:	learn: 0.0572935	total: 1.11s	remaining: 488ms
# 278:	learn: 0.0572836	total: 1.11s	remaining: 484ms
# 279:	learn: 0.0572731	total: 1.12s	remaining: 480ms
# 280:	learn: 0.0572570	total: 1.12s	remaining: 476ms
# 281:	learn: 0.0572472	total: 1.13s	remaining: 472ms
# 282:	learn: 0.0572288	total: 1.13s	remaining: 468ms
# 283:	learn: 0.0572210	total: 1.14s	remaining: 464ms
# 284:	learn: 0.0572136	total: 1.14s	remaining: 460ms
# 285:	learn: 0.0572032	total: 1.14s	remaining: 456ms
# 286:	learn: 0.0571956	total: 1.15s	remaining: 452ms
# 287:	learn: 0.0571848	total: 1.15s	remaining: 448ms
# 288:	learn: 0.0571716	total: 1.16s	remaining: 444ms
# 289:	learn: 0.0571541	total: 1.16s	remaining: 440ms
# 290:	learn: 0.0571418	total: 1.16s	remaining: 436ms
# 291:	learn: 0.0571290	total: 1.17s	remaining: 432ms
# 292:	learn: 0.0571239	total: 1.17s	remaining: 428ms
# 293:	learn: 0.0571019	total: 1.18s	remaining: 424ms
# 294:	learn: 0.0570948	total: 1.18s	remaining: 420ms
# 295:	learn: 0.0570696	total: 1.18s	remaining: 416ms
# 296:	learn: 0.0570574	total: 1.19s	remaining: 412ms
# 297:	learn: 0.0570473	total: 1.19s	remaining: 408ms
# 298:	learn: 0.0570390	total: 1.2s	remaining: 404ms
# 299:	learn: 0.0570210	total: 1.2s	remaining: 401ms
# 300:	learn: 0.0570142	total: 1.21s	remaining: 397ms
# 301:	learn: 0.0570037	total: 1.21s	remaining: 393ms
# 302:	learn: 0.0569920	total: 1.21s	remaining: 389ms
# 303:	learn: 0.0569825	total: 1.22s	remaining: 385ms
# 304:	learn: 0.0569724	total: 1.22s	remaining: 381ms
# 305:	learn: 0.0569650	total: 1.23s	remaining: 377ms
# 306:	learn: 0.0569597	total: 1.23s	remaining: 373ms
# 307:	learn: 0.0569475	total: 1.23s	remaining: 369ms
# 308:	learn: 0.0569375	total: 1.24s	remaining: 365ms
# 309:	learn: 0.0569195	total: 1.24s	remaining: 361ms
# 310:	learn: 0.0569033	total: 1.25s	remaining: 356ms
# 311:	learn: 0.0568944	total: 1.25s	remaining: 352ms
# 312:	learn: 0.0568831	total: 1.25s	remaining: 348ms
# 313:	learn: 0.0568655	total: 1.26s	remaining: 344ms
# 314:	learn: 0.0568574	total: 1.26s	remaining: 340ms
# 315:	learn: 0.0568425	total: 1.26s	remaining: 336ms
# 316:	learn: 0.0568272	total: 1.27s	remaining: 332ms
# 317:	learn: 0.0568134	total: 1.27s	remaining: 328ms
# 318:	learn: 0.0567914	total: 1.28s	remaining: 324ms
# 319:	learn: 0.0567782	total: 1.28s	remaining: 321ms
# 320:	learn: 0.0567653	total: 1.29s	remaining: 317ms
# 321:	learn: 0.0567485	total: 1.29s	remaining: 313ms
# 322:	learn: 0.0567423	total: 1.29s	remaining: 309ms
# 323:	learn: 0.0567315	total: 1.3s	remaining: 305ms
# 324:	learn: 0.0567224	total: 1.3s	remaining: 301ms
# 325:	learn: 0.0567139	total: 1.31s	remaining: 297ms
# 326:	learn: 0.0567056	total: 1.31s	remaining: 293ms
# 327:	learn: 0.0567012	total: 1.31s	remaining: 289ms
# 328:	learn: 0.0566856	total: 1.32s	remaining: 285ms
# 329:	learn: 0.0566768	total: 1.32s	remaining: 281ms
# 330:	learn: 0.0566724	total: 1.33s	remaining: 277ms
# 331:	learn: 0.0566531	total: 1.33s	remaining: 273ms
# 332:	learn: 0.0566422	total: 1.33s	remaining: 268ms
# 333:	learn: 0.0566347	total: 1.34s	remaining: 264ms
# 334:	learn: 0.0566304	total: 1.34s	remaining: 260ms
# 335:	learn: 0.0566245	total: 1.35s	remaining: 256ms
# 336:	learn: 0.0566153	total: 1.35s	remaining: 252ms
# 337:	learn: 0.0566115	total: 1.35s	remaining: 248ms
# 338:	learn: 0.0565993	total: 1.36s	remaining: 244ms
# 339:	learn: 0.0565790	total: 1.36s	remaining: 240ms
# 340:	learn: 0.0565646	total: 1.37s	remaining: 236ms
# 341:	learn: 0.0565587	total: 1.37s	remaining: 232ms
# 342:	learn: 0.0565486	total: 1.37s	remaining: 228ms
# 343:	learn: 0.0565444	total: 1.38s	remaining: 224ms
# 344:	learn: 0.0565267	total: 1.38s	remaining: 220ms
# 345:	learn: 0.0565093	total: 1.39s	remaining: 216ms
# 346:	learn: 0.0565040	total: 1.39s	remaining: 212ms
# 347:	learn: 0.0564937	total: 1.39s	remaining: 208ms
# 348:	learn: 0.0564886	total: 1.4s	remaining: 204ms
# 349:	learn: 0.0564782	total: 1.4s	remaining: 200ms
# 350:	learn: 0.0564703	total: 1.41s	remaining: 196ms
# 351:	learn: 0.0564522	total: 1.41s	remaining: 192ms
# 352:	learn: 0.0564481	total: 1.41s	remaining: 188ms
# 353:	learn: 0.0564336	total: 1.42s	remaining: 184ms
# 354:	learn: 0.0564266	total: 1.42s	remaining: 180ms
# 355:	learn: 0.0564217	total: 1.43s	remaining: 176ms
# 356:	learn: 0.0564178	total: 1.43s	remaining: 172ms
# 357:	learn: 0.0564035	total: 1.43s	remaining: 168ms
# 358:	learn: 0.0563996	total: 1.44s	remaining: 164ms
# 359:	learn: 0.0563949	total: 1.44s	remaining: 160ms
# 360:	learn: 0.0563710	total: 1.45s	remaining: 156ms
# 361:	learn: 0.0563632	total: 1.45s	remaining: 152ms
# 362:	learn: 0.0563488	total: 1.45s	remaining: 148ms
# 363:	learn: 0.0563451	total: 1.46s	remaining: 144ms
# 364:	learn: 0.0563395	total: 1.46s	remaining: 140ms
# 365:	learn: 0.0563287	total: 1.47s	remaining: 136ms
# 366:	learn: 0.0563160	total: 1.47s	remaining: 132ms
# 367:	learn: 0.0563118	total: 1.47s	remaining: 128ms
# 368:	learn: 0.0563083	total: 1.48s	remaining: 124ms
# 369:	learn: 0.0562943	total: 1.48s	remaining: 120ms
# 370:	learn: 0.0562861	total: 1.49s	remaining: 116ms
# 371:	learn: 0.0562830	total: 1.49s	remaining: 112ms
# 372:	learn: 0.0562774	total: 1.49s	remaining: 108ms
# 373:	learn: 0.0562662	total: 1.5s	remaining: 104ms
# 374:	learn: 0.0562592	total: 1.5s	remaining: 100ms
# 375:	learn: 0.0562437	total: 1.5s	remaining: 96.1ms
# 376:	learn: 0.0562239	total: 1.51s	remaining: 92.1ms
# 377:	learn: 0.0562021	total: 1.51s	remaining: 88.1ms
# 378:	learn: 0.0561792	total: 1.52s	remaining: 84.1ms
# 379:	learn: 0.0561696	total: 1.52s	remaining: 80.1ms
# 380:	learn: 0.0561621	total: 1.53s	remaining: 76.1ms
# 381:	learn: 0.0561538	total: 1.53s	remaining: 72.1ms
# 382:	learn: 0.0561307	total: 1.53s	remaining: 68.1ms
# 383:	learn: 0.0561232	total: 1.54s	remaining: 64.1ms
# 384:	learn: 0.0561161	total: 1.54s	remaining: 60.1ms
# 385:	learn: 0.0561089	total: 1.55s	remaining: 56.1ms
# 386:	learn: 0.0561055	total: 1.55s	remaining: 52.1ms
# 387:	learn: 0.0560986	total: 1.55s	remaining: 48.1ms
# 388:	learn: 0.0560907	total: 1.56s	remaining: 44ms
# 389:	learn: 0.0560861	total: 1.56s	remaining: 40ms
# 390:	learn: 0.0560794	total: 1.56s	remaining: 36ms
# 391:	learn: 0.0560671	total: 1.57s	remaining: 32ms
# 392:	learn: 0.0560646	total: 1.57s	remaining: 28ms
# 393:	learn: 0.0560546	total: 1.58s	remaining: 24ms
# 394:	learn: 0.0560513	total: 1.58s	remaining: 20ms
# 395:	learn: 0.0560442	total: 1.58s	remaining: 16ms
# 396:	learn: 0.0560222	total: 1.59s	remaining: 12ms
# 397:	learn: 0.0560063	total: 1.59s	remaining: 8.01ms
# 398:	learn: 0.0559976	total: 1.6s	remaining: 4ms
# 399:	learn: 0.0559944	total: 1.6s	remaining: 0us
# CatBoost 5-Fold CV RMSLE (v32): 0.060490 ± 0.001238
# Finished CV...
# Manual Ensemble Weights (v32): {'xgboost': 0.35, 'lightgbm': 0.3, 'catboost': 0.35}
# Starting meta-learner tuning...
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [12:23:14] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# Finished meta-learner tuning...
# Best Meta-Learner Parameters (v32): {'reg_lambda': 0, 'reg_alpha': 0.1, 'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.1}
# Starting neural network training...
# Finished neural network training...
# XGBoost Feature Importance (v32):
#  Duration_MET_Interaction            0.843303
# Duration_Heart_Rate_Interaction     0.119072
# Heart_Rate_Body_Temp_Interaction    0.009336
# Sex                                 0.008075
# Female_Duration                     0.004009
# Sex_Heart_Rate_Interaction          0.003950
# Body_Temp_HR_Ratio                  0.003177
# HR_Ratio                            0.003029
# Male_Duration                       0.002557
# Heart_Rate                          0.000670
# Age_Duration                        0.000447
# Weight                              0.000430
# MET_approx                          0.000420
# Estimated_Calories                  0.000326
# BMR                                 0.000189
# HR_Age                              0.000175
# Body_Temp_Age_Interaction           0.000143
# HR_Rest                             0.000099
# Body_Temp                           0.000092
# Age                                 0.000079
# Height                              0.000079
# Heart_Rate_BMI_Interaction          0.000058
# Age_BMI_Interaction                 0.000049
# Duration                            0.000048
# HR_Duration_Ratio                   0.000045
# BMR_Duration                        0.000038
# Body_Temp_BMI_Interaction           0.000035
# Duration_Body_Temp                  0.000035
# BMI                                 0.000033
# Age_Group                           0.000000
# HR_Max                              0.000000
# dtype: float32
# LightGBM Feature Importance (v32):
#  Weight                              1645
# Duration_MET_Interaction            1319
# Heart_Rate_Body_Temp_Interaction    1140
# HR_Duration_Ratio                    917
# HR_Rest                              862
# MET_approx                           844
# BMR                                  728
# Body_Temp_HR_Ratio                   708
# Female_Duration                      688
# HR_Ratio                             681
# Heart_Rate                           675
# Male_Duration                        669
# Height                               638
# HR_Age                               550
# Heart_Rate_BMI_Interaction           550
# Duration_Heart_Rate_Interaction      519
# Sex_Heart_Rate_Interaction           517
# Body_Temp                            501
# Age_Duration                         497
# Age_BMI_Interaction                  477
# Body_Temp_BMI_Interaction            473
# Estimated_Calories                   424
# BMI                                  408
# BMR_Duration                         362
# Body_Temp_Age_Interaction            346
# HR_Max                               191
# Age                                  156
# Duration_Body_Temp                   149
# Sex                                   31
# Duration                              20
# Age_Group                             15
# dtype: int32

# %%
# Updated best parameters (initial)
BEST_XGB_PARAMS = {'learning_rate': 0.05, 'max_depth': 7,
                   'n_estimators': 400, 'reg_alpha': 3.0,
                   'reg_lambda': 2.0,
                   "objective": 'reg:squaredlogerror', 'device':'gpu'}

BEST_XGB_PARAMS = {'gamma': 0, 'learning_rate': 0.1, 'n_estimators': 600,
                   'objective': 'reg:squaredlogerror', 'reg_alpha': 0.5, 'reg_lambda': 0}
BEST_XGB_PARAMS = {'reg_lambda': 5, 'reg_alpha': 0.5, 'objective': 'reg:squaredlogerror', 'n_estimators': 600, 'learning_rate': 0.1, 'gamma': 0}
BEST_LGBM_PARAMS = {'reg_lambda': 0.5, 'reg_alpha': 1.5,
                    'num_leaves': 60, 'n_estimators': 300, 'min_child_samples': 30,
                    'max_depth': 15,
                    'learning_rate': 0.05, 'device': 'gpu'}
BEST_CB_PARAMS = {'learning_rate': 0.03, 'l2_leaf_reg': 7, 'iterations': 400, 'depth': 9, 'bagging_temperature': 0}
BEST_CB_PARAMS =  {'learning_rate': 0.03, 'l2_leaf_reg': 7, 'iterations': 600, 'depth': 9, 'bagging_temperature': 0}
BEST_CB_PARAMS = {'learning_rate': 0.03, 'l2_leaf_reg': 7, 'iterations': 600, 'depth': 13, 'bagging_temperature': 0.5}
